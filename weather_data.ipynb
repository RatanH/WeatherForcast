# %% [markdown]
# ## Project Topic : Weather Data Analysis and Forecast

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

weather1 = pd.read_csv("./IndianWeatherRepository.csv")
weather1.head(10)
# Out:
#   country location_name          region  latitude  longitude      timezone  \
# 0   India    Ashoknagar  Madhya Pradesh     24.57      77.72  Asia/Kolkata
# 1   India        Raisen  Madhya Pradesh     23.33      77.80  Asia/Kolkata
# 2   India    Chhindwara  Madhya Pradesh     22.07      78.93  Asia/Kolkata
# 3   India         Betul  Madhya Pradesh     21.86      77.93  Asia/Kolkata
# 4   India   Hoshangabad  Madhya Pradesh     22.75      77.72  Asia/Kolkata
# 5   India        Sehore  Madhya Pradesh     23.20      77.08  Asia/Kolkata
# 6   India      Jabalpur  Madhya Pradesh     23.17      79.95  Asia/Kolkata
# 7   India   Narsimhapur  Madhya Pradesh     22.95      79.20  Asia/Kolkata
# 8   India         Panna  Madhya Pradesh     24.72      80.20  Asia/Kolkata
# 9   India        Ujjain  Madhya Pradesh     23.18      75.77  Asia/Kolkata
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1693286100  2023-08-29 10:45                 27.5
# ...

# %%
max(weather1.temperature_celsius)
# Out:
# 38.3

# %%
print(weather1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48693 entries, 0 to 48692
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       48693 non-null  object
#  1   location_name                 48693 non-null  object
#  2   region                        48693 non-null  object
#  3   latitude                      48693 non-null  float64
#  4   longitude                     48693 non-null  float64
#  5   timezone                      48693 non-null  object
#  6   last_updated_epoch            48693 non-null  int64
#  7   last_updated                  48693 non-null  object
#  8   temperature_celsius           48693 non-null  float64
#  9   temperature_fahrenheit        48693 non-null  float64
#  10  condition_text                48693 non-null  object
#  11  wind_mph                      48693 non-null  float64
# ...

# %%
print(weather1.isnull().sum())
# Out:
# country                         0
# location_name                   0
# region                          0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# ...

# %%
weather1.columns
# Out:
# Index(['country', 'location_name', 'region', 'latitude', 'longitude',
#        'timezone', 'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
print(weather1['condition_text'].str.strip().str.lower().unique())
print(weather1['condition_text'].str.strip().str.lower().nunique())
# Out:
# ['partly cloudy' 'sunny' 'cloudy' 'mist' 'patchy rain possible' 'overcast'
#  'patchy light rain with thunder' 'light rain shower'
#  'moderate or heavy rain shower' 'clear' 'light rain'
#  'torrential rain shower' 'fog' 'thundery outbreaks possible'
#  'patchy light drizzle' 'moderate rain' 'patchy light rain'
#  'moderate rain at times' 'heavy rain' 'heavy rain at times'
#  'light drizzle' 'moderate or heavy rain with thunder'
#  'patchy snow possible' 'moderate or heavy snow showers'
#  'light snow showers' 'moderate or heavy snow with thunder'
#  'patchy light snow with thunder' 'light sleet' 'light freezing rain'
#  'patchy light snow' 'patchy moderate snow']
# 31

# %%
#count values of each unique value
weather1['condition_text'].value_counts()
# Out:
# condition_text
# Clear                                  24140
# Mist                                    6847
# Partly cloudy                           5865
# Patchy rain possible                    4058
# Light rain shower                       2496
# Fog                                      964
# Cloudy                                   959
# Overcast                                 883
# Sunny                                    772
# Moderate or heavy rain shower            383
# Light rain                               337
# Patchy light drizzle                     153
# Light drizzle                            148
# Moderate rain                            137
# Moderate or heavy rain with thunder      129
# Patchy light rain                        107
# Moderate rain at times                    69
# Patchy light rain with thunder            65
# Heavy rain                                53
# Thundery outbreaks possible               51
# ...

# %%
X = weather1.drop(weather1.iloc[:,0:8],axis=1)
X = X.drop(X.loc[:,['condition_text','wind_direction']],axis=1)
X = X.drop(X.iloc[:,26:],axis=1)
X
# Out:
#        temperature_celsius  temperature_fahrenheit  wind_mph  wind_kph  \
# 0                     27.5                    81.5      12.8      20.5
# 1                     27.5                    81.5       9.6      15.5
# 2                     26.3                    79.3      11.4      18.4
# 3                     25.6                    78.1      10.5      16.9
# 4                     27.2                    81.0      10.1      16.2
# ...                    ...                     ...       ...       ...
# 48688                 16.0                    60.8       2.2       3.6
# 48689                 16.2                    61.1       2.5       4.0
# 48690                 22.6                    72.6       3.6       5.8
# 48691                 21.9                    71.4       3.4       5.4
# 48692                 23.6                    74.5       2.5       4.0
#
#        wind_degree  pressure_mb  pressure_in  precip_mm  precip_in  humidity  \
# ...

# %%
y = weather1['condition_text']
y
# Out:
# 0               Partly cloudy
# 1                       Sunny
# 2               Partly cloudy
# 3                      Cloudy
# 4                      Cloudy
#                  ...
# 48688                    Mist
# 48689                   Clear
# 48690                    Mist
# 48691    Patchy rain possible
# 48692                   Clear
# Name: condition_text, Length: 48693, dtype: object

# %%
#correlation of X variables
print(X.corr())
# Out:
#                               temperature_celsius  temperature_fahrenheit  \
# temperature_celsius                      1.000000                0.999983
# temperature_fahrenheit                   0.999983                1.000000
# wind_mph                                 0.219654                0.219640
# wind_kph                                 0.219286                0.219271
# wind_degree                              0.187296                0.187287
# pressure_mb                             -0.703725               -0.703721
# pressure_in                             -0.704698               -0.704693
# precip_mm                                0.064307                0.064301
# precip_in                                0.063748                0.063741
# humidity                                 0.182234                0.182214
# cloud                                    0.199669                0.199651
# feels_like_celsius                       0.983694                0.983699
# ...

# %%
mumbai= weather1[weather1['location_name']=='Mumbai']
mumbai
# Out:
#       country location_name       region  latitude  longitude      timezone  \
# 367     India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
# 912     India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
# 1461    India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
# 1462    India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
# 2010    India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
# ...       ...           ...          ...       ...        ...           ...
# 46871   India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
# 46872   India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
# 47420   India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
# 47964   India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
# 48510   India        Mumbai  Maharashtra     18.98      72.83  Asia/Kolkata
#
# ...

# %%
X = mumbai.drop(mumbai.iloc[:,0:8],axis=1)
X = X.drop(X.loc[:,['condition_text','wind_direction']],axis=1)
X = X.drop(X.iloc[:,26:],axis=1)
X
# Out:
#        temperature_celsius  temperature_fahrenheit  wind_mph  wind_kph  \
# 367                   27.0                    80.6       8.1      13.0
# 912                   28.0                    82.4       4.3       6.8
# 1461                  27.0                    80.6       4.3       6.8
# 1462                  26.9                    80.4       2.2       3.6
# 2010                  29.0                    84.2       4.3       6.8
# ...                    ...                     ...       ...       ...
# 46871                 29.0                    84.2       5.6       9.0
# 46872                 28.3                    82.9       5.1       8.3
# 47420                 24.0                    75.2       8.1      13.0
# 47964                 27.0                    80.6       4.3       6.8
# 48510                 26.0                    78.8       5.6       9.0
#
#        wind_degree  pressure_mb  pressure_in  precip_mm  precip_in  humidity  \
# ...

# %%
y = mumbai['condition_text']
y
# Out:
# 367      Moderate or heavy rain shower
# 912                               Mist
# 1461                              Mist
# 1462                             Clear
# 2010                              Mist
#                      ...
# 46871                       Light rain
# 46872                    Partly cloudy
# 47420                       Light rain
# 47964                             Mist
# 48510                             Mist
# Name: condition_text, Length: 103, dtype: object

# %%
#mumbai
print(X.corr())
# Out:
#                               temperature_celsius  temperature_fahrenheit  \
# temperature_celsius                      1.000000                0.999998
# temperature_fahrenheit                   0.999998                1.000000
# wind_mph                                -0.076683               -0.076607
# wind_kph                                -0.079593               -0.079522
# wind_degree                              0.159845                0.159518
# pressure_mb                              0.438202                0.438069
# pressure_in                              0.436857                0.436716
# precip_mm                               -0.300356               -0.300233
# precip_in                               -0.278199               -0.278079
# humidity                                -0.549301               -0.549201
# cloud                                   -0.596358               -0.596337
# feels_like_celsius                       0.857120                0.857149
# ...

# %%
#mumbai
sns.heatmap(X.corr(),cmap='Reds',annot=False)
# Out:
# <Axes: >

# %%
weather2 = weather1.drop(weather1.iloc[:,0:8],axis=1)
weather2 = weather2.drop(weather2.loc[:,['condition_text','temperature_fahrenheit']],axis=1)
weather2 = weather2.drop(weather2.iloc[:,26:],axis=1)
print(weather2.columns)
weather2
# Out:
# Index(['temperature_celsius', 'wind_mph', 'wind_kph', 'wind_degree',
#        'wind_direction', 'pressure_mb', 'pressure_in', 'precip_mm',
#        'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index'],
#       dtype='object')
#        temperature_celsius  wind_mph  wind_kph  wind_degree wind_direction  \
# 0                     27.5      12.8      20.5          281            WNW
# 1                     27.5       9.6      15.5          287            WNW
# 2                     26.3      11.4      18.4          317             NW
# 3                     25.6      10.5      16.9          297            WNW
# ...

# %%
# get dummies
dum_weather2 = pd.get_dummies(weather2,drop_first=True)
print(dum_weather2.columns)
dum_weather2
# Out:
# Index(['temperature_celsius', 'wind_mph', 'wind_kph', 'wind_degree',
#        'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity',
#        'cloud', 'feels_like_celsius', 'feels_like_fahrenheit', 'visibility_km',
#        'visibility_miles', 'uv_index', 'gust_mph', 'gust_kph',
#        'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
#        'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
#        'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index',
#        'air_quality_gb-defra-index', 'wind_direction_ENE',
#        'wind_direction_ESE', 'wind_direction_N', 'wind_direction_NE',
#        'wind_direction_NNE', 'wind_direction_NNW', 'wind_direction_NW',
#        'wind_direction_S', 'wind_direction_SE', 'wind_direction_SSE',
#        'wind_direction_SSW', 'wind_direction_SW', 'wind_direction_W',
#        'wind_direction_WNW', 'wind_direction_WSW'],
#       dtype='object')
# ...

# %%
#weather1 = pd.read_csv("./IndianWeatherRepository.csv",index_col='last_updated')
#weather1 = weather1[['temperature_celsius']]
#weather1 = pd.iloc

#idx = pd.to_datetime( weather1.index ).to_period("M")
#weather1.index = idx
#weather1
# Out:
#               temperature_celsius
# last_updated
# 2023-08                      27.5
# 2023-08                      27.5
# 2023-08                      26.3
# 2023-08                      25.6
# 2023-08                      27.2
# ...                           ...
# 2023-11                      16.0
# 2023-11                      16.2
# 2023-11                      22.6
# 2023-11                      21.9
# 2023-11                      23.6
#
# [48693 rows x 1 columns]

# %%
weather1.dtypes
# Out:
# temperature_celsius    float64
# dtype: object
